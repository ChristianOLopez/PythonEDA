# %%
import pandas as pd
import numpy as np
import seaborn as sns # importando las librerias necesarias para el EDA

# %%
from google.colab import drive
drive.mount("/content/drive/") # conectando con el drive personal
# Out:
# Mounted at /content/drive/

# %%
salary = pd.read_csv("/content/drive/MyDrive/PYTHON ESENCIALS/IT Salary Survey EU  2020.csv") # cargando el archivo desde el drive ya conectado (poner ruta)

# %%
salary.head() # Primeros registros
# Out:
#              Timestamp  ...  Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR
# 0  24/11/2020 11:14:15  ...                                                NaN
# 1  24/11/2020 11:14:16  ...                                                NaN
# 2  24/11/2020 11:14:21  ...                                                NaN
# 3  24/11/2020 11:15:24  ...                                                NaN
# 4  24/11/2020 11:15:46  ...                                                NaN
#
# [5 rows x 23 columns]

# %%
salary.describe() # datos estadísticos
# Out:
#                Age  ...  Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week
# count  1226.000000  ...                                         373.000000
# mean     32.509788  ...                                          12.967828
# std       5.663804  ...                                          15.275174
# min      20.000000  ...                                           0.000000
# 25%      29.000000  ...                                           0.000000
# 50%      32.000000  ...                                           0.000000
# 75%      35.000000  ...                                          30.000000
# max      69.000000  ...                                          40.000000
#
# [8 rows x 4 columns]

# %%
salary.tail() # últimos registros
# Out:
#                 Timestamp  ...  Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR
# 1248  18/01/2021 15:05:50  ...                                                NaN
# 1249  18/01/2021 17:46:02  ...                                                  0
# 1250  18/01/2021 23:20:35  ...                                                NaN
# 1251  19/01/2021 10:17:58  ...                                                  0
# 1252  19/01/2021 12:01:11  ...                                                600
#
# [5 rows x 23 columns]

# %%
salary.shape # filas y columnas
# Out:
# (1253, 23)

# %%
salary.columns # que campos tiene
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'City', 'Position ',
#        'Total years of experience', 'Years of experience in Germany',
#        'Seniority level', 'Your main technology / programming language',
#        'Other technologies/programming languages you use often',
#        'Yearly brutto salary (without bonus and stocks) in EUR',
#        'Yearly bonus + stocks in EUR',
#        'Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country',
#        'Annual bonus+stocks one year ago. Only answer if staying in same country',
#        'Number of vacation days', 'Employment status', 'Сontract duration',
#        'Main language at work', 'Company size', 'Company type',
#        'Have you lost your job due to the coronavirus outbreak?',
#        'Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week',
# ...

# %%
salary.nunique() # cuantos valores por campo (no incluye vacíos)
# Out:
# Timestamp                                                                                                                  1248
# Age                                                                                                                          40
# Gender                                                                                                                        3
# City                                                                                                                        119
# Position                                                                                                                    148
# Total years of experience                                                                                                    48
# Years of experience in Germany                                                                                               53
# ...

# %%
salary["Gender"].unique() # que valores hay por columna. Vacío lo identifica como "nan"
# Out:
# array(['Male', 'Female', nan, 'Diverse'], dtype=object)

# %%
salary["Company size"].unique()
# Out:
# array(['51-100', '101-1000', '11-50', '1000+', nan, 'up to 10'],
#       dtype=object)

# %%
salary.isnull().sum() # cuantos registros estan vacios por cada campo
# Out:
# Timestamp                                                                                                                    0
# Age                                                                                                                         27
# Gender                                                                                                                      10
# City                                                                                                                         0
# Position                                                                                                                     6
# Total years of experience                                                                                                   16
# Years of experience in Germany                                                                                              32
# ...

# %%
basic = salary.drop(['Yearly bonus + stocks in EUR',
       'Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country',
       'Annual bonus+stocks one year ago. Only answer if staying in same country',
       'Number of vacation days', 'Employment status', 'Сontract duration',
       'Main language at work', 'Company size', 'Company type',
       'Have you lost your job due to the coronavirus outbreak?',
       'Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week',
       'Have you received additional monetary support from your employer due to Work From Home? If yes, how much in 2020 in EUR'], axis=1) # quitando campos que no se van a usar y creando la nueva base basic

# %%
basic.head() # mostrando la nueva base con los campos principales
# Out:
#              Timestamp  ...  Yearly brutto salary (without bonus and stocks) in EUR
# 0  24/11/2020 11:14:15  ...                                            80000.0
# 1  24/11/2020 11:14:16  ...                                            80000.0
# 2  24/11/2020 11:14:21  ...                                           120000.0
# 3  24/11/2020 11:15:24  ...                                            54000.0
# 4  24/11/2020 11:15:46  ...                                            62000.0
#
# [5 rows x 11 columns]

# %%
basic.info() # estructura de la base
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 11 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Timestamp                                               1253 non-null   object
#  1   Age                                                     1226 non-null   float64
#  2   Gender                                                  1243 non-null   object
#  3   City                                                    1253 non-null   object
#  4   Position                                                1247 non-null   object
#  5   Total years of experience                               1237 non-null   object
#  6   Years of experience in Germany                          1221 non-null   object
#  7   Seniority level                                         1241 non-null   object
# ...

# %%
basic["Timestamp"] = pd.to_datetime(basic["Timestamp"]) # convirtiendo el campo Timestamp de objeto a fecha
basic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 11 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Timestamp                                               1253 non-null   datetime64[ns]
#  1   Age                                                     1226 non-null   float64
#  2   Gender                                                  1243 non-null   object
#  3   City                                                    1253 non-null   object
#  4   Position                                                1247 non-null   object
#  5   Total years of experience                               1237 non-null   object
#  6   Years of experience in Germany                          1221 non-null   object
#  7   Seniority level                                         1241 non-null   object
# ...

# %%
basic["Año"] = basic["Timestamp"].dt.year # crea 5 nuevas columnas con los datos de la fecha en timestamp
basic["Year"] = basic["Timestamp"].dt.year
basic["Month"] = basic["Timestamp"].dt.month
basic["Day"] = basic["Timestamp"].dt.day
basic["Hour"] = basic["Timestamp"].dt.hour

# %%
basic = basic.drop(columns=["Año"]) # eliminar columnas
basic.tail()
# Out:
#                Timestamp   Age Gender         City  ...  Year Month Day Hour
# 1248 2021-01-18 15:05:50  31.0   Male       Berlin  ...  2021     1  18   15
# 1249 2021-01-18 17:46:02  33.0   Male       Berlin  ...  2021     1  18   17
# 1250 2021-01-18 23:20:35  39.0   Male       Munich  ...  2021     1  18   23
# 1251 2021-01-19 10:17:58  26.0   Male  Saarbrücken  ...  2021     1  19   10
# 1252 2021-01-19 12:01:11  26.0   Male       Berlin  ...  2021     1  19   12
#
# [5 rows x 15 columns]

# %%
basic.head()
# Out:
#             Timestamp   Age Gender    City  ...  Year Month Day Hour
# 0 2020-11-24 11:14:15  26.0   Male  Munich  ...  2020    11  24   11
# 1 2020-11-24 11:14:16  26.0   Male  Berlin  ...  2020    11  24   11
# 2 2020-11-24 11:14:21  29.0   Male  Berlin  ...  2020    11  24   11
# 3 2020-11-24 11:15:24  28.0   Male  Berlin  ...  2020    11  24   11
# 4 2020-11-24 11:15:46  37.0   Male  Berlin  ...  2020    11  24   11
#
# [5 rows x 15 columns]

# %%
basic.groupby("Gender") # agrupando por genero

# %%
basic.groupby("Gender").mean() # la media por cada género
# Out:
#                Age  ...       Hour
# Gender              ...
# Diverse  27.500000  ...  11.000000
# Female   31.261780  ...  14.031250
# Male     32.740777  ...  14.143947
#
# [3 rows x 6 columns]

# %%
basic["Yearly brutto salary (without bonus and stocks) in EUR"] = pd.to_numeric(basic["Yearly brutto salary (without bonus and stocks) in EUR"]) # convirtiendo a numeric

# %%
basic.info() # ya aparecen los nuevos campos de fecha creados
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 15 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Timestamp                                               1253 non-null   datetime64[ns]
#  1   Age                                                     1226 non-null   float64
#  2   Gender                                                  1243 non-null   object
#  3   City                                                    1253 non-null   object
#  4   Position                                                1247 non-null   object
#  5   Total years of experience                               1237 non-null   object
#  6   Years of experience in Germany                          1221 non-null   object
#  7   Seniority level                                         1241 non-null   object
# ...

# %%
basic.groupby("Seniority level")

# %%
basic.groupby("Seniority level").mean() # media por cargos y niveles
# Out:
#                                                  Age  ...       Hour
# Seniority level                                       ...
# C-Level                                    36.000000  ...  15.000000
# C-level executive manager                  31.000000  ...  12.000000
# CTO                                        32.000000  ...  21.000000
# Director                                   33.000000  ...  23.000000
# Entry level                                23.000000  ...  16.000000
# Head                                       36.720930  ...  14.409091
# Intern                                     22.000000  ...   9.000000
# Junior                                     28.666667  ...  13.873418
# Key                                        28.000000  ...  11.000000
# Lead                                       34.777778  ...  14.168675
# Manager                                    36.000000  ...  12.000000
# Middle                                     30.206128  ...  13.931694
# ...
